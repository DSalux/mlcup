# %%
import pandas as pd

# %%
import pandas as pd
df_tr = pd.read_parquet("data/processed/train_slim.parquet")
df_tr.head(50)  # или sample(50)
# Out:
#         id  ItemID  SellerID  resolution             brand_name  \
# 0   159385   78312      1218           0                 ACTRUM
# 1   288616  141999      1374           0               Red Line
# 2   108090   53306      1448           0        Talwar Brothers
# 3   415607  202599       715           0                unknown
# 4   332391  163725       715           0                unknown
# 5   139903   68645       715           0                unknown
# 6    30559   15306      2759           0                unknown
# 7   319690  157310      2759           0                unknown
# 8    79124   39370      2759           0                unknown
# 9   393163  192392     11969           0                Телетай
# 10  102250   50423      6729           0                unknown
# 11  368595  180984       153           0                unknown
# 12   70313   35075      5602           0                   HB-H
# 13  373064  183205      4865           0                Harizma
# ...
